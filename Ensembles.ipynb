# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import *

import settings
import utils

# %% [markdown]
# ### Get and Load Data

# %%
# DOWNLOAD data and save in data folder (data/BCHARTS-BITSTAMPUSD.csv) https://www.quandl.com/api/v3/datasets/BCHARTS/BITSTAMPUSD/data.csv?order=asc
df = pd.read_csv(settings.PATH_DATA, sep=',')

# %%
df.rename(columns={'Volume (BTC)': 'Volume_BTC', 'Volume (Currency)': 'Volume_Currency', 'Weighted Price': 'Weighted_Price'}, inplace=True)

# %%
df.head()
# Out:
#          Date  Open  High   Low  Close  Volume_BTC  Volume_Currency  \
# 0  2011-09-13  5.80  6.00  5.65   5.97   58.371382       346.097389
# 1  2011-09-14  5.58  5.72  5.52   5.53   61.145984       341.854813
# 2  2011-09-15  5.12  5.24  5.00   5.13   80.140795       408.259002
# 3  2011-09-16  4.82  4.87  4.80   4.85   39.914007       193.763147
# 4  2011-09-17  4.87  4.87  4.87   4.87    0.300000         1.461000
#
#    Weighted_Price
# 0        5.929231
# 1        5.590798
# 2        5.094272
# 3        4.854515
# 4        4.870000

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Drop rows with 0.00 values

# %%
df = utils.dropna(df)

# %% [markdown]
# ### Transformation

# %% [markdown]
# Create column target with class [UP, KEEP, DOWN]

# %%
df['Target'] = 1 # 'KEEP'
df.loc[df.Open + (df.Open * settings.PERCENT_UP) < df.Close, 'Target'] = 2 # 'UP'
df.loc[df.Open - (df.Open * settings.PERCENT_DOWN) > df.Close, 'Target'] = 3 # 'DOWN'

# %%
df.head(20)
# Out:
#           Date  Open  High   Low  Close  Volume_BTC  Volume_Currency  \
# 0   2011-09-13  5.80  6.00  5.65   5.97   58.371382       346.097389
# 1   2011-09-14  5.58  5.72  5.52   5.53   61.145984       341.854813
# 2   2011-09-15  5.12  5.24  5.00   5.13   80.140795       408.259002
# 3   2011-09-16  4.82  4.87  4.80   4.85   39.914007       193.763147
# 4   2011-09-17  4.87  4.87  4.87   4.87    0.300000         1.461000
# 5   2011-09-18  4.87  4.92  4.81   4.92  119.812800       579.843103
# 6   2011-09-19  4.90  4.90  4.90   4.90   20.000000        98.000000
# 7   2011-09-20  4.92  5.66  4.92   5.66   89.280711       481.049263
# 8   2011-09-21  5.70  5.79  5.66   5.66   17.629322       100.594234
# 9   2011-09-22  5.68  5.72  5.68   5.72   43.778422       249.403941
# 10  2011-09-23  5.70  5.72  5.70   5.72   20.680037       118.023015
# 11  2011-09-24  5.70  5.76  5.68   5.68   90.587066       518.383945
# 12  2011-09-25  6.05  6.05  6.05   6.05   12.220000        73.931000
# 13  2011-09-26  6.06  6.06  4.80   4.80   39.578463       236.800854
# 14  2011-09-27  4.85  4.92  4.85   4.92   24.354500       119.225060
# 15  2011-09-28  4.90  4.91  4.82   4.82   83.053326       403.846606
# 16  2011-09-29  4.81  4.82  4.81   4.82   46.964500       226.197226
# 20  2011-10-03  4.85  4.87  4.83   4.87   30.575950       148.225232
# 21  2011-10-04  4.86  5.30  4.80   4.98  142.521622       701.881480
# 22  2011-10-05  4.92  6.25  4.80   4.92  113.720000       571.945500
#
#     Weighted_Price  Target
# 0         5.929231       1
# 1         5.590798       1
# 2         5.094272       1
# 3         4.854515       1
# 4         4.870000       1
# 5         4.839576       1
# 6         4.900000       1
# 7         5.388054       2
# 8         5.706075       1
# 9         5.696960       1
# 10        5.707099       1
# 11        5.722494       1
# 12        6.050000       1
# 13        5.983073       3
# 14        4.895402       1
# 15        4.862498       1
# 16        4.816345       1
# 20        4.847772       1
# 21        4.924737       1
# 22        5.029419       1

# %%
print('Number of rows: {}, Number of columns: {}'.format(*df.shape))
print('Number of UP rows: {}, Number of DOWN rows: {}'.format(len(df[df.Target == 2]), len(df[df.Target == 3])))
# Out:
# Number of rows: 2018, Number of columns: 9
# Number of UP rows: 183, Number of DOWN rows: 126

# %% [markdown]
# Create columns from Date to Day, Month and Year.

# %%
df['Date'] = pd.to_datetime(df['Date'])

df['Year'] = 0
df['Year'] = df['Date'].dt.year

df['Month'] = 0
df['Month'] = df['Date'].dt.month

df['Day'] = 0
df['Day'] = df['Date'].dt.day

# %%
print('Number of rows: {}, Number of columns: {}'.format(*df.shape))
# Out:
# Number of rows: 2018, Number of columns: 12

# %% [markdown]
# Transformation previous values from Open, High, Low and Close columns.

# %%
# create PREV_DAYS * len(cols) new columns
cols = ['Open', 'High', 'Low', 'Close', 'Volume_BTC', 'Volume_Currency', 'Weighted_Price']
for i in cols:
    col = i
    for idx in range(settings.PREV_DAYS):
        prev = idx + 1
        df[col+'-'+str(prev)] = df.Close.shift(prev)
df = df.dropna()

# %%
print('Number of rows: {}, Number of columns: {}'.format(*df.shape))
# Out:
# Number of rows: 2008, Number of columns: 82

# %%
df.head()
# Out:
#          Date  Open  High   Low  Close  Volume_BTC  Volume_Currency  \
# 10 2011-09-23  5.70  5.72  5.70   5.72   20.680037       118.023015
# 11 2011-09-24  5.70  5.76  5.68   5.68   90.587066       518.383945
# 12 2011-09-25  6.05  6.05  6.05   6.05   12.220000        73.931000
# 13 2011-09-26  6.06  6.06  4.80   4.80   39.578463       236.800854
# 14 2011-09-27  4.85  4.92  4.85   4.92   24.354500       119.225060
#
#     Weighted_Price  Target  Year        ...          Weighted_Price-1  \
# 10        5.707099       1  2011        ...                      5.72
# 11        5.722494       1  2011        ...                      5.72
# 12        6.050000       1  2011        ...                      5.68
# 13        5.983073       3  2011        ...                      6.05
# 14        4.895402       1  2011        ...                      4.80
#
#     Weighted_Price-2  Weighted_Price-3  Weighted_Price-4  Weighted_Price-5  \
# 10              5.66              5.66              4.90              4.92
# 11              5.72              5.66              5.66              4.90
# 12              5.72              5.72              5.66              5.66
# 13              5.68              5.72              5.72              5.66
# 14              6.05              5.68              5.72              5.72
#
#     Weighted_Price-6  Weighted_Price-7  Weighted_Price-8  Weighted_Price-9  \
# 10              4.87              4.85              5.13              5.53
# 11              4.92              4.87              4.85              5.13
# 12              4.90              4.92              4.87              4.85
# 13              5.66              4.90              4.92              4.87
# 14              5.66              5.66              4.90              4.92
#
#     Weighted_Price-10
# 10               5.97
# 11               5.53
# 12               5.13
# 13               4.85
# 14               4.87
#
# [5 rows x 82 columns]

# %% [markdown]
# ### Split

# %%
train, test = utils.split_df2(df)

# %%
excl = ['Open', 'High', 'Low', 'Close', 'Target', 'Date', 'Year', 'Day']
cols = [c for c in df.columns if c not in excl]

# %% [markdown]
# ### RandomForest

# %%
# train
rf = RandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=17, verbose=0)
model1 = rf.fit(train[cols], train['Target'])

# predict
y_pred = model1.predict(test[cols])
y_pred_proba = model1.predict_proba(test[cols])
y_true = test['Target']

# metric
utils.metrics(y_true, y_pred, y_pred_proba)
# Out:
# Cross Entropy: 0.483762382449
# Accuracy: 0.846613545817
# Coeficiente Kappa: 0.260465294253
# Report:              precision    recall  f1-score   support
#
#        KEEP       0.89      0.95      0.92       430
#          UP       0.36      0.26      0.30        38
#        DOWN       0.46      0.18      0.26        34
#
# avg / total       0.82      0.85      0.83       502
#
# Confusion Matrix:
#
# Predicted    1   2   3  __all__
# Actual
# 1          409  15   6      430
# 2           27  10   1       38
# 3           25   3   6       34
# __all__    461  28  13      502
#
#
# Overall Statistics:
#
# Accuracy: 0.846613545817
# 95% CI: (0.8120637086763679, 0.87701419388967428)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 0.999999961304
# Kappa: 0.260465294253
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                        1          2          3
# Population                                   502        502        502
# P: Condition positive                        430         38         34
# N: Condition negative                         72        464        468
# Test outcome positive                        461         28         13
# Test outcome negative                         41        474        489
# TP: True Positive                            409         10          6
# TN: True Negative                             20        446        461
# FP: False Positive                            52         18          7
# FN: False Negative                            21         28         28
# TPR: (Sensitivity, hit rate, recall)    0.951163   0.263158   0.176471
# TNR=SPC: (Specificity)                  0.277778   0.961207   0.985043
# PPV: Pos Pred Value (Precision)         0.887202   0.357143   0.461538
# NPV: Neg Pred Value                     0.487805   0.940928    0.94274
# FPR: False-out                          0.722222  0.0387931  0.0149573
# FDR: False Discovery Rate               0.112798   0.642857   0.538462
# FNR: Miss Rate                         0.0488372   0.736842   0.823529
# ACC: Accuracy                           0.854582   0.908367   0.930279
# F1 score                                 0.91807    0.30303   0.255319
# MCC: Matthews correlation coefficient   0.293009   0.258605   0.255532
# Informedness                            0.228941   0.224365   0.161513
# Markedness                              0.375007   0.298071   0.404279
# Prevalence                              0.856574  0.0756972  0.0677291
# LR+: Positive likelihood ratio           1.31699    6.78363    11.7983
# LR-: Negative likelihood ratio          0.175814    0.76658   0.836034
# DOR: Diagnostic odds ratio               7.49084    8.84921    14.1122
# FOR: False omission rate                0.512195  0.0590717  0.0572597

# %% [markdown]
# ### Bagging

# %%
# train
ba = BaggingClassifier(n_estimators=1000, n_jobs=-1, random_state=17, verbose=0)
model1 = ba.fit(train[cols], train['Target'])

# predict
y_pred = model1.predict(test[cols])
y_pred_proba = model1.predict_proba(test[cols])
y_true = test['Target']

# metric
utils.metrics(y_true, y_pred, y_pred_proba)
# Out:
# Cross Entropy: 0.642261428761
# Accuracy: 0.854581673307
# Coeficiente Kappa: 0.343732091691
# Report:              precision    recall  f1-score   support
#
#        KEEP       0.90      0.95      0.93       430
#          UP       0.35      0.24      0.28        38
#        DOWN       0.46      0.32      0.38        34
#
# avg / total       0.83      0.85      0.84       502
#
# Confusion Matrix:
#
# Predicted    1   2   3  __all__
# Actual
# 1          409  12   9      430
# 2           25   9   4       38
# 3           18   5  11       34
# __all__    452  26  24      502
#
#
# Overall Statistics:
#
# Accuracy: 0.854581673307
# 95% CI: (0.82066366783807776, 0.88425146904760732)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 0.999543917913
# Kappa: 0.343732091691
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                        1          2          3
# Population                                   502        502        502
# P: Condition positive                        430         38         34
# N: Condition negative                         72        464        468
# Test outcome positive                        452         26         24
# Test outcome negative                         50        476        478
# TP: True Positive                            409          9         11
# TN: True Negative                             29        447        455
# FP: False Positive                            43         17         13
# FN: False Negative                            21         29         23
# TPR: (Sensitivity, hit rate, recall)    0.951163   0.236842   0.323529
# TNR=SPC: (Specificity)                  0.402778   0.963362   0.972222
# PPV: Pos Pred Value (Precision)         0.904867   0.346154   0.458333
# NPV: Neg Pred Value                         0.58   0.939076   0.951883
# FPR: False-out                          0.597222  0.0366379  0.0277778
# FDR: False Discovery Rate              0.0951327   0.653846   0.541667
# FNR: Miss Rate                         0.0488372   0.763158   0.676471
# ACC: Accuracy                            0.87251   0.908367   0.928287
# F1 score                                0.927438    0.28125    0.37931
# MCC: Matthews correlation coefficient   0.414263   0.238965   0.348313
# Informedness                            0.353941   0.200204   0.295752
# Markedness                              0.484867   0.285229   0.410216
# Prevalence                              0.856574  0.0756972  0.0677291
# LR+: Positive likelihood ratio           1.59264     6.4644    11.6471
# LR-: Negative likelihood ratio          0.121251   0.792182   0.695798
# DOR: Diagnostic odds ratio               13.1351    8.16024    16.7391
# FOR: False omission rate                    0.42  0.0609244  0.0481172

# %% [markdown]
# ### ExtraTrees

# %%
# train
et = ExtraTreesClassifier(n_estimators=1000, n_jobs=-1, random_state=17, verbose=0)
model1 = et.fit(train[cols], train['Target'])

# predict
y_pred = model1.predict(test[cols])
y_pred_proba = model1.predict_proba(test[cols])
y_true = test['Target']

# metric
utils.metrics(y_true, y_pred, y_pred_proba)
# Out:
# Cross Entropy: 0.49575847427
# Accuracy: 0.840637450199
# Coeficiente Kappa: 0.168874172185
# Report:              precision    recall  f1-score   support
#
#        KEEP       0.88      0.96      0.92       430
#          UP       0.28      0.18      0.22        38
#        DOWN       0.33      0.06      0.10        34
#
# avg / total       0.79      0.84      0.81       502
#
# Confusion Matrix:
#
# Predicted    1   2  3  __all__
# Actual
# 1          413  14  3      430
# 2           30   7  1       38
# 3           28   4  2       34
# __all__    471  25  6      502
#
#
# Overall Statistics:
#
# Accuracy: 0.840637450199
# 95% CI: (0.80563300951307526, 0.87156666965292273)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 1.0
# Kappa: 0.168874172185
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                        1          2           3
# Population                                   502        502         502
# P: Condition positive                        430         38          34
# N: Condition negative                         72        464         468
# Test outcome positive                        471         25           6
# Test outcome negative                         31        477         496
# TP: True Positive                            413          7           2
# TN: True Negative                             14        446         464
# FP: False Positive                            58         18           4
# FN: False Negative                            17         31          32
# TPR: (Sensitivity, hit rate, recall)    0.960465   0.184211   0.0588235
# TNR=SPC: (Specificity)                  0.194444   0.961207    0.991453
# PPV: Pos Pred Value (Precision)         0.876858       0.28    0.333333
# NPV: Neg Pred Value                     0.451613    0.93501    0.935484
# FPR: False-out                          0.805556  0.0387931  0.00854701
# FDR: False Discovery Rate               0.123142       0.72    0.666667
# FNR: Miss Rate                         0.0395349   0.815789    0.941176
# ACC: Accuracy                           0.850598    0.90239    0.928287
# F1 score                                0.916759   0.222222         0.1
# MCC: Matthews correlation coefficient   0.225573   0.176823    0.116255
# Informedness                             0.15491   0.145417   0.0502765
# Markedness                              0.328471    0.21501    0.268817
# Prevalence                              0.856574  0.0756972   0.0677291
# LR+: Positive likelihood ratio            1.1923    4.74854     6.88235
# LR-: Negative likelihood ratio          0.203322   0.848714     0.94929
# DOR: Diagnostic odds ratio                5.8641    5.59498        7.25
# FOR: False omission rate                0.548387  0.0649895   0.0645161

# %% [markdown]
# ### GradientBoosting

# %%
# train
gr = GradientBoostingClassifier(n_estimators=1000, max_depth=10, warm_start=True, learning_rate=0.08, random_state=17, verbose=0)
model1 = gr.fit(train[cols], train['Target'])

# predict
y_pred = model1.predict(test[cols])
y_pred_proba = model1.predict_proba(test[cols])
y_true = test['Target']

# metric
utils.metrics(y_true, y_pred, y_pred_proba)
# Out:
# Cross Entropy: 0.80996788522
# Accuracy: 0.852589641434
# Coeficiente Kappa: 0.365598743084
# Report:              precision    recall  f1-score   support
#
#        KEEP       0.91      0.94      0.93       430
#          UP       0.35      0.37      0.36        38
#        DOWN       0.47      0.24      0.31        34
#
# avg / total       0.84      0.85      0.84       502
#
# Confusion Matrix:
#
# Predicted    1   2   3  __all__
# Actual
# 1          406  17   7      430
# 2           22  14   2       38
# 3           17   9   8       34
# __all__    445  40  17      502
#
#
# Overall Statistics:
#
# Accuracy: 0.852589641434
# 95% CI: (0.81851083603014907, 0.88244503760679804)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 0.991385188156
# Kappa: 0.365598743084
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                        1          2          3
# Population                                   502        502        502
# P: Condition positive                        430         38         34
# N: Condition negative                         72        464        468
# Test outcome positive                        445         40         17
# Test outcome negative                         57        462        485
# TP: True Positive                            406         14          8
# TN: True Negative                             33        438        459
# FP: False Positive                            39         26          9
# FN: False Negative                            24         24         26
# TPR: (Sensitivity, hit rate, recall)    0.944186   0.368421   0.235294
# TNR=SPC: (Specificity)                  0.458333   0.943966   0.980769
# PPV: Pos Pred Value (Precision)          0.91236       0.35   0.470588
# NPV: Neg Pred Value                     0.578947   0.948052   0.946392
# FPR: False-out                          0.541667  0.0560345  0.0192308
# FDR: False Discovery Rate              0.0876404       0.65   0.529412
# FNR: Miss Rate                          0.055814   0.631579   0.764706
# ACC: Accuracy                           0.874502   0.900398   0.930279
# F1 score                                   0.928   0.358974   0.313725
# MCC: Matthews correlation coefficient   0.444703   0.305135   0.300157
# Informedness                            0.402519   0.312387   0.216063
# Markedness                              0.491307   0.298052    0.41698
# Prevalence                              0.856574  0.0756972  0.0677291
# LR+: Positive likelihood ratio           1.74311     6.5749    12.2353
# LR-: Negative likelihood ratio          0.121776    0.66907     0.7797
# DOR: Diagnostic odds ratio               14.3141    9.82692    15.6923
# FOR: False omission rate                0.421053  0.0519481  0.0536082

# %% [markdown]
# ### AdaBoost

# %%
# train
ab = AdaBoostClassifier(n_estimators=500, random_state=17)
model1 = ab.fit(train[cols], train['Target'])

# predict
y_pred = model1.predict(test[cols])
y_pred_proba = model1.predict_proba(test[cols])
y_true = test['Target']

# metric
utils.metrics(y_true, y_pred, y_pred_proba)
# Out:
# Cross Entropy: 1.08663940731
# Accuracy: 0.832669322709
# Coeficiente Kappa: 0.2335320634
# Report:              precision    recall  f1-score   support
#
#        KEEP       0.89      0.94      0.91       430
#          UP       0.24      0.21      0.22        38
#        DOWN       0.50      0.21      0.29        34
#
# avg / total       0.81      0.83      0.82       502
#
# Confusion Matrix:
#
# Predicted    1   2   3  __all__
# Actual
# 1          403  22   5      430
# 2           28   8   2       38
# 3           23   4   7       34
# __all__    454  34  14      502
#
#
# Overall Statistics:
#
# Accuracy: 0.832669322709
# 95% CI: (0.79708302781739193, 0.86427866639521944)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 0.999999808346
# Kappa: 0.2335320634
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                        1          2          3
# Population                                   502        502        502
# P: Condition positive                        430         38         34
# N: Condition negative                         72        464        468
# Test outcome positive                        454         34         14
# Test outcome negative                         48        468        488
# TP: True Positive                            403          8          7
# TN: True Negative                             21        438        461
# FP: False Positive                            51         26          7
# FN: False Negative                            27         30         27
# TPR: (Sensitivity, hit rate, recall)    0.937209   0.210526   0.205882
# TNR=SPC: (Specificity)                  0.291667   0.943966   0.985043
# PPV: Pos Pred Value (Precision)         0.887665   0.235294        0.5
# NPV: Neg Pred Value                       0.4375   0.935897   0.944672
# FPR: False-out                          0.708333  0.0560345  0.0149573
# FDR: False Discovery Rate               0.112335   0.764706        0.5
# FNR: Miss Rate                         0.0627907   0.789474   0.794118
# ACC: Accuracy                           0.844622   0.888446   0.932271
# F1 score                                0.911765   0.222222   0.291667
# MCC: Matthews correlation coefficient   0.272805   0.162627   0.291374
# Informedness                            0.228876   0.154492   0.190925
# Markedness                              0.325165   0.171192   0.444672
# Prevalence                              0.856574  0.0756972  0.0677291
# LR+: Positive likelihood ratio           1.32312    3.75709    13.7647
# LR-: Negative likelihood ratio          0.215282   0.836337   0.806176
# DOR: Diagnostic odds ratio               6.14597    4.49231    17.0741
# FOR: False omission rate                  0.5625  0.0641026  0.0553279

# %% [markdown]
# ### VotingClassifier

# %%
# train
v = VotingClassifier(estimators=[
        ('rf', rf), ('ba', ba), ('et', et), ('gr', gr), ('ab', ab)
    ], voting='hard', n_jobs=-1)
model1 = v.fit(train[cols], train['Target'])

# predict
y_pred = model1.predict(test[cols])
# y_pred_proba = model1.predict_proba(test[cols])
y_true = test['Target']

# metric
utils.metrics(y_true, y_pred)
# Out:
# /Users/bukosabino/envs/btctrader/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# Accuracy: 0.846613545817
# Coeficiente Kappa: 0.243383964923
# Report:              precision    recall  f1-score   support
#
#        KEEP       0.89      0.96      0.92       430
#          UP       0.35      0.24      0.28        38
#        DOWN       0.42      0.15      0.22        34
#
# avg / total       0.81      0.85      0.82       502
#
# Confusion Matrix:
#
# Predicted    1   2   3  __all__
# Actual
# 1          411  13   6      430
# 2           28   9   1       38
# 3           25   4   5       34
# __all__    464  26  12      502
#
#
# Overall Statistics:
#
# Accuracy: 0.846613545817
# 95% CI: (0.8120637086763679, 0.87701419388967428)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 0.99999999849
# Kappa: 0.243383964923
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                       1          2          3
# Population                                  502        502        502
# P: Condition positive                       430         38         34
# N: Condition negative                        72        464        468
# Test outcome positive                       464         26         12
# Test outcome negative                        38        476        490
# TP: True Positive                           411          9          5
# TN: True Negative                            19        447        461
# FP: False Positive                           53         17          7
# FN: False Negative                           19         29         29
# TPR: (Sensitivity, hit rate, recall)   0.955814   0.236842   0.147059
# TNR=SPC: (Specificity)                 0.263889   0.963362   0.985043
# PPV: Pos Pred Value (Precision)        0.885776   0.346154   0.416667
# NPV: Neg Pred Value                         0.5   0.939076   0.940816
# FPR: False-out                         0.736111  0.0366379  0.0149573
# FDR: False Discovery Rate              0.114224   0.653846   0.583333
# FNR: Miss Rate                         0.044186   0.763158   0.852941
# ACC: Accuracy                          0.856574   0.908367   0.928287
# F1 score                               0.919463    0.28125   0.217391
# MCC: Matthews correlation coefficient  0.291129   0.238965   0.217311
# Informedness                           0.219703   0.200204   0.132102
# Markedness                             0.385776   0.285229   0.357483
# Prevalence                             0.856574  0.0756972  0.0677291
# LR+: Positive likelihood ratio          1.29846     6.4644    9.83193
# LR-: Negative likelihood ratio         0.167442   0.792182   0.865893
# DOR: Diagnostic odds ratio              7.75472    8.16024    11.3547
# FOR: False omission rate                    0.5  0.0609244  0.0591837

# %%
# train
v = VotingClassifier(estimators=[
        ('rf', rf), ('ba', ba), ('et', et), ('gr', gr), ('ab', ab)
    ], voting='hard', n_jobs=-1)
model1 = v.fit(train[cols], train['Target'])

# predict
y_pred = model1.predict(test[cols])
# y_pred_proba = model1.predict_proba(test[cols])
y_true = test['Target']

# metric
utils.metrics(y_true, y_pred)
# Out:
# /Users/bukosabino/envs/btctrader/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:540: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)

# %% [markdown]
# ### Conclusions

# %% [markdown]
# RandomForest and GradientBoosting are working very good. We need study them a few more...
